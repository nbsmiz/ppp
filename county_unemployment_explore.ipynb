# %% [markdown]
# https://www.census.gov/data/datasets/time-series/demo/popest/2010s-counties-total.html#par_textimage_70769902

# %%
import pandas as pd

# %%
unemployment = (pd.read_csv("static/unemployment_county_14mo.txt", sep="|",
                            names=['laus', 'fipsstate', 'fipscount', 'title',
                                   'period', 'labor','employed', 'level', 'rate'],
                            index_col=False))

# %%
unemployment.head()
# Out:
#                 laus  fipsstate  fipscount  \
# 0   CN0100100000000         1.0        1.0
# 1   CN0100300000000         1.0        3.0
# 2   CN0100500000000         1.0        5.0
# 3   CN0100700000000         1.0        7.0
# 4   CN0100900000000         1.0        9.0
#
#                                         title       period         labor  \
# 0   Autauga County, AL                            May-19         26,271
# 1   Baldwin County, AL                            May-19         98,311
# 2   Barbour County, AL                            May-19          8,416
# 3   Bibb County, AL                               May-19          8,605
# 4   Blount County, AL                             May-19         25,136
#
#        employed       level      rate
# 0       25,680         591        2.2
# 1       96,129       2,182        2.2
# 2        8,152         264        3.1
# 3        8,391         214        2.5
# 4       24,589         547        2.2

# %%
unemployment.dropna()
# Out:
#                     laus  fipsstate  fipscount  \
# 0       CN0100100000000         1.0        1.0
# 1       CN0100300000000         1.0        3.0
# 2       CN0100500000000         1.0        5.0
# 3       CN0100700000000         1.0        7.0
# 4       CN0100900000000         1.0        9.0
# ...                  ...        ...        ...
# 45061   CN7214500000000        72.0      145.0
# 45062   CN7214700000000        72.0      147.0
# 45063   CN7214900000000        72.0      149.0
# 45064   CN7215100000000        72.0      151.0
# 45065   CN7215300000000        72.0      153.0
#
#                                             title       period         labor  \
# 0       Autauga County, AL                            May-19         26,271
# 1       Baldwin County, AL                            May-19         98,311
# 2       Barbour County, AL                            May-19          8,416
# 3       Bibb County, AL                               May-19          8,605
# ...

# %%
unemployment.iloc[0].period.strip()
# Out:
# 'May-19'

# %%
unemployment[unemployment['level'] == 591]
# Out:
# Empty DataFrame
# Columns: [laus, fipsstate, fipscount, title, period, labor, employed, level, rate]
# Index: []

# %%
unemployment
# Out:
# Empty DataFrame
# Columns: [laus, fipsstate, fipscount, title, period, labor, employed, level, rate]
# Index: []
